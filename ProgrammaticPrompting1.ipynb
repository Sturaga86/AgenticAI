# %% [markdown]
# <a href="https://colab.research.google.com/github/Sturaga86/AgenticAI/blob/main/ProgrammaticPrompting1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !!pip install litellm

# Important!!!
#
# <---- Set your 'OPENAI_API_KEY' as a secret over there with the "key" icon
#
#
import os
from google.colab import userdata
api_key = userdata.get('GEMINI_API_KEY')
os.environ['GEMINI_API_KEY'] = api_key

# %%
from litellm import completion
from typing import List, Dict
import os


# def generate_response(messages: List[Dict]) -> str:
#     """Call LLM to get response"""
#     response = completion(
#         model="gemini/gemini-1.5-pro", # Reverting to the most common Gemini Pro model name
#         messages=messages,
#         max_tokens=1024,
#         api_key=os.environ['GEMINI_API_KEY'] # Explicitly pass the API key
#     )
#     return response.choices[0].message.content

def generate_response(messages: List[Dict]) -> str:
  """Call LLM to get response"""
  try:
      response = completion(
          # pattern: gemini/<model-name>
          model="gemini/gemini-2.5-flash",
          messages=messages,
          max_tokens=4096
      )
      return response.choices[0].message.content
  except Exception as e:
      return f"Error: {str(e)}"

messages = [
    {"role": "system", "content": "You are an expert software engineer that prefers functional programming."},
    {"role": "user", "content": "Write a function to swap the keys and values in a dictionary."}
]

response = generate_response(messages)
print(response)
# Out:
# As an expert software engineer with a preference for functional programming, the goal is to create a function that is **pure**, **immutable**, and **returns a new data structure** rather than modifying an existing one.
#
# For swapping keys and values in a dictionary, this means:
# 1.  **Immutability**: The original dictionary will remain unchanged. A new dictionary will be created and returned.
# 2.  **Purity**: Given the same input dictionary, the function will always produce the same output dictionary, with no side effects.
#
# ### Key Considerations for Swapping:
#
# *   **Hashability**: When values from the original dictionary become keys in the new dictionary, they *must* be hashable (e.g., numbers, strings, tuples, frozen sets). If any original value is unhashable (e.g., lists, sets, other dictionaries), a `TypeError` will occur. Type hints will enforce this.
# ...
